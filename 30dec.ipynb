# %% [markdown]
# <a href="https://colab.research.google.com/github/shreyamishra1602/PotatoDiseasePredictor/blob/main/30dec.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
for i in range(2):
    for j in range(3):
        print(i,j)
# Out:
# 0 0
# 0 1
# 0 2
# 1 0
# 1 1
# 1 2

# %%
rows=int(input("enter the number of rows: "))
cols=int(input("enter the number of columns: "))
for i in range(rows):
  for j in range(cols):
      print("×",end="")
  print()
# Out:
# enter the number of rows: 5
# enter the number of columns: 6
# ××××××
# ××××××
# ××××××
# ××××××
# ××××××

# %%
for i in range(3):
  j=0
  while j<2:
    print (i,j)
    j+=1
# Out:
# 0 0
# 0 1
# 1 0
# 1 1
# 2 0
# 2 1
